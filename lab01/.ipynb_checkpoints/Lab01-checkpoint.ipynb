# %% [markdown]
# You need to download the jupyterthemes and uncertainties packages. The former is for the theme, latter for uncertainty calculations <br>
# Use the following for installing: <br>
# pip install jupyterthemes <br>
# pip install uncertainties

# %%
import jupyterthemes as jt
jt.get_themes()
# Out:
# ['chesterish',
#  'grade3',
#  'gruvboxd',
#  'gruvboxl',
#  'monokai',
#  'oceans16',
#  'onedork',
#  'solarizedd',
#  'solarizedl']

# %%
# https://towardsdatascience.com/customize-your-jupyter-notebook-theme-in-2-lines-of-code-fc726cea1513
# !jt -t onedork -f fira -fs 13 -nf ptsans -nfs 11 -N -kl -cursw 5 -cursc r -cellw 95% -T
# !jt -r
# !jt -t grade3 -T -N -kl -cursc r -cellw 90%
jt.jtplot.style()

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy
from scipy.optimize import curve_fit
import astropy.units as u
import pandas as pd
from uncertainties import ufloat
import scipy.stats as stats
from uncertainties import ufloat
import matplotlib.ticker as mticker

# %%
mu0 = 1.25663706212*10**-6

# %%
current = np.arange(0.5,0.95,0.05)
mass0 = np.array([.570, .553, .532, .514, .490, .474, .453, .432, .413])
errcurrent = np.ones(9)*0.01
errmass = np.ones(9) *0.001
deltac = np.ones(9)*0.05
deltam = mass0 - 180.786

# %%
func = lambda x, a, b: a*x +b
xlin = np.linspace(.4,1,100)

popt, pcov = curve_fit(func, current, deltam, sigma = errcurrent, p0=None)

sigma = np.sqrt(0.01**2 + (0.001)**2)*np.ones(len(current))
(bparam,bcov) = np.polyfit(current,deltam,1,w=1/sigma,cov=True)
bfitp = np.poly1d(bparam)
byfit = bfitp(current)
bchi = np.sum(((deltam - byfit)/errcurrent)**2)
bdof = len(current) - len(bparam)
bredchi = bchi/bdof
bp_value = 1 - stats.chi2.cdf(bchi, df=bdof)
m = ufloat(bparam[0],np.sqrt(bcov[0,0]))
b = ufloat(bparam[1],np.sqrt(bcov[1,1]))
print(f"m = {m:.2e}\nb = {b:.2e}")

plt.errorbar(current,deltam,yerr=errmass,xerr=errcurrent,fmt='o')
plt.text(0.8, -180.250,f"m = {m:.2e}\nb  = {b:.2e}",backgroundcolor="lightgrey")
# plt.scatter(current,deltam)
plt.plot(xlin, func(xlin, *popt), 'r', label=f"mx + b")
plt.title("Current vs. Mass (B-field calibration)")
plt.legend()
plt.grid(True)
plt.savefig("cali_B_plot.png")
plt.show()
# Out:
# m = (-3.96+/-0.04)e-01
# b = (-1.80+/-0.00)e+02

# %%
resid = deltam-func(current, *popt)
plt.scatter(current,resid)
plt.hlines(0,0.5,0.9,"black")
plt.grid(False)
plt.title("Residuals of B-field linear fit")
plt.savefig("cali_B_plot_resid.png")
plt.show()

# %% [markdown]
# We were having an issue finding the gravitational acceleration to use, so we have just asked the Wolfram Alpha database: <br>
# $g = 9.8026 \frac{m}{s^2}$ <br>
# We couldn't find the error, so we will assume $+/- 0.01 \frac{m}{s^2}$

# %%
g = ufloat(9.8026, 0.01)
Bslope = ufloat(popt[0],np.sqrt(bcov[0,0]))

B=-1*(Bslope*(g)/0.01)/1000
print(B)
# Out:
# 0.389+/-0.004

# %%
data = pd.read_csv("lab01_data.csv")
# online data via wiki, to be checked later

# %%
data['high diff'] = data['high(g)'] - data['init']
data['low diff'] = data['low(g)'] - data['init']
data['high/low diff diff'] = data['high diff']-data['low diff']
data['high/low diff diff avg'] = data['high/low diff diff']/2
data["our classification"] = None
init_mass = data['mass(g)'][data['name'] == " empty vial"]
data['mass'] = data["mass(g)"] - float(init_mass)

# %%
# #Don't think this is working since the elements are type np.float64
# data["low(g)"] *= u.g
# data["high(g)"] *= u.g
# data["far(g)"] *= u.g
# data["init"] *= u.g
# data["mass(g)"] *= u.g
# data["mass"] *= u.g
# data["height(cm)"] *= u.cm
# data["high diff"] *= u.g
# data["low diff"] *= u.g|
# data["high/low diff diff"] *= u.g
# data["online chi(cm3/mol)"] *= (u.cm)**3/u.mol

# %% [markdown]
# If High diff is positive and Low diff negative: then the sample alligns with the B field and is pulling it up, thus paramagnet
# If High diff is negative and Low diff positive: then the sample anti-alligns with the B field and is pushing down, thus diamagnet
# If High diff and Low diff have the same sign then the field doesn't effect the magnetization and it is a ferromagnet

# %% [markdown]
# Looking over it manually (cause coding that part was annoying) the classifcations were added.

# %%
data.loc[data["name"] == " copper", "our classification"] = "diamagnetic"
data.loc[data["name"] == " aluminum", "our classification"] = "paramagnetic"
data.loc[data["name"] == " titanium", "our classification"] = "paramagnetic"
data.loc[data["name"] == " bismuth", "our classification"] = "diamagnetic"
data.loc[data["name"] == " colbalt wire", "our classification"] = "paramagnetic"
data.loc[data["name"] == " pyrolytic graphite", "our classification"] = "diamagnetic"
data.loc[data["name"] == " neodymium choride hexahydrate", "our classification"] = "paramagnetic"
data.loc[data["name"] == " gadolinium oxide", "our classification"] = "ferromagnetic"
data.loc[data["name"] == " erbium oxide", "our classification"] = "ferromagnetic"
data.loc[data["name"] == " mohrs salt", "our classification"] = "ferromagnetic"
data.loc[data["name"] == " irom alum", "our classification"] = "ferromagnetic"
data.loc[data["name"] == " blue vitriol", "our classification"] = "paramagnetic"
data.loc[data["name"] == " copper acetate", "our classification"] = "paramagnetic"
data.loc[data["name"] == " manganese oxide", "our classification"] = "ferromagnetic"
data.loc[data["name"] == " manganese choride tetrahydrate", "our classification"] = "diamagnetic"
data.loc[data["name"] == " nickel-zinc ferrite", "our classification"] = "paramagnetic"
data.loc[data["name"] == " empty vial", "our classification"] = "diamagnetic"
data.loc[data["name"] == " iodized salt", "our classification"] = "diamagnetic"
data.loc[data["name"] == " himalanan salt", "our classification"] = "diamagnetic"
data.loc[data["name"] == " Rust on paper", "our classification"] = "ferromagnetic"

# %%
data # printing out our data to be read
# Out:
#             sample                             name   low(g)  high(g)  \
# 0                1                           copper  180.764  180.782
# 1                2                         aluminum  180.779  180.762
# 2                3                         titanium  180.874  180.656
# 3                4                          bismuth  180.701  180.842
# 4                5                     colbalt wire  180.941  180.579
# 5                6               pyrolytic graphite  180.705  180.841
# 6                7    neodymium choride hexahydrate  180.939  180.585
# 7                8                 gadolinium oxide  180.155  180.403
# 8                9                     erbium oxide  180.480  180.465
# 9               10                       mohrs salt  180.035  180.426
# 10              11                        irom alum  180.020  180.495
# 11              12                     blue vitriol  180.839  180.693
# 12              13                   copper acetate  180.804  180.734
# 13              14                  manganese oxide  180.472  180.566
# 14              15   manganese choride tetrahydrate  180.512  180.913
# 15              16              nickel-zinc ferrite  180.622  180.792
# 16              17                       empty vial  180.771  180.780
# 17        1 (redo)                           copper  180.764  180.784
# 18        2 (redo)                         aluminum  180.781  180.764
# 19        3 (redo)                         titanium  180.877  180.655
# 20        4 (redo)                          bismuth  180.705  180.844
# 21        5 (redo)                     colbalt wire  180.943  180.586
# 22              1*                     iodized salt  180.746  180.769
# 23              2*                   himalanan salt  180.748  180.768
# 24       16 (redo)              nickel-zinc ferrite  181.692  179.777
# 25  5 (second day)                     colbalt wire  180.757  180.580
# 26  2 (second day)                         aluminum  180.762  180.753
# 27  1 (second day)                           copper  180.760  180.770
# 28              18                    Rust on paper  180.763  180.763
#
#      far(g)     init online classification  online chi(cm3/mol)  height(cm)  \
# 0   180.772      NaN           diamagnetic            -0.000005        3.20
# 1   180.772      NaN          paramagnetic             0.000017        3.00
# 2   180.772      NaN          paramagnetic             0.000153        3.00
# 3   180.772      NaN           diamagnetic            -0.000280        3.30
# 4   180.771      NaN         ferromagnetic                  NaN        3.20
# 5   180.771  180.772                   NaN                  NaN        3.20
# 6   180.772  180.772          paramagnetic                  NaN        3.10
# 7   180.768  180.774                   NaN             0.053200        3.40
# 8   180.767  180.773                   NaN             0.073920        3.35
# 9   180.774  180.773                   NaN                  NaN        3.20
# 10  180.773  180.772          paramagnetic                  NaN        3.20
# 11  180.772  180.770                   NaN             0.001330        3.50
# 12  180.771  180.771                   NaN                  NaN        3.30
# 13  180.770  180.772                   NaN             0.004850        2.90
# 14  180.772  180.775                   NaN             0.014350        3.50
# 15  180.772  180.776          paramagnetic                  NaN        3.40
# 16  180.776  180.775                   NaN                  NaN        3.85
# 17  180.775  180.774           diamagnetic            -0.000005        3.20
# 18  180.774  180.774          paramagnetic             0.000017        3.00
# 19  180.774  180.775          paramagnetic             0.000153        3.00
# 20  180.775  180.774           diamagnetic            -0.000280        3.30
# 21  180.766  180.766         ferromagnetic                  NaN        3.20
# 22  180.759  180.759                   NaN                  NaN        3.50
# 23  180.758  180.758                   NaN                  NaN        3.70
# 24  180.762  180.772          paramagnetic                  NaN        3.40
# 25  180.939  180.762         ferromagnetic                  NaN        3.20
# 26  180.771  180.763          paramagnetic             0.000017        3.00
# 27  180.749  180.760           diamagnetic            -0.000005        3.20
# 28  180.759  180.760                   NaN                  NaN         NaN
#
#     mass(g)       type  molar mass  high diff  low diff  high/low diff diff  \
# 0    28.163      solid   63.546000        NaN       NaN                 NaN
# 1    10.619      solid   26.981539        NaN       NaN                 NaN
# 2    15.890      solid   47.867000        NaN       NaN                 NaN
# 3    21.187  non-solid  208.980400        NaN       NaN                 NaN
# 4     3.206      solid   58.933195        NaN       NaN                 NaN
# 5     4.090      solid   12.011000      0.069    -0.067               0.136
# 6     7.514  non-solid  358.692700     -0.187     0.167              -0.354
# 7     9.378  non-solid  362.498200     -0.371    -0.619               0.248
# 8    12.247  non-solid  382.516200     -0.308    -0.293              -0.015
# 9     6.427  non-solid  392.130000     -0.347    -0.738               0.391
# 10    5.053  non-solid  482.250000     -0.277    -0.752               0.475
# 11    7.176  non-solid  249.685000     -0.077     0.069              -0.146
# 12    6.419  non-solid  199.650000     -0.037     0.033              -0.070
# 13    8.110  non-solid   70.937440     -0.206    -0.300               0.094
# 14    6.738  non-solid  925.968800      0.138    -0.263               0.401
# 15    8.426  non-solid  234.381000      0.016    -0.154               0.170
# 16    2.942      solid         NaN      0.005    -0.004               0.009
# 17   28.163      solid   63.546000      0.010    -0.010               0.020
# 18   10.619      solid   26.981539     -0.010     0.007              -0.017
# 19   15.890      solid   47.867000     -0.120     0.102              -0.222
# 20   21.187  non-solid  208.980400      0.070    -0.069               0.139
# 21    3.206      solid   58.933195     -0.180     0.177              -0.357
# 22    7.749  non-solid   58.442800      0.010    -0.013               0.023
# 23    7.713  non-solid   58.442800      0.010    -0.010               0.020
# 24    8.426  non-solid  234.381000     -0.995     0.920              -1.915
# 25    3.206      solid   58.933195     -0.182    -0.005              -0.177
# 26   10.619      solid   26.981539     -0.010    -0.001              -0.009
# 27   28.163      solid   63.546000      0.010     0.000               0.010
# 28      NaN  non-solid         NaN      0.003     0.003               0.000
#
#     high/low diff diff avg our classification    mass
# 0                      NaN        diamagnetic  25.221
# 1                      NaN       paramagnetic   7.677
# 2                      NaN       paramagnetic  12.948
# 3                      NaN        diamagnetic  18.245
# 4                      NaN       paramagnetic   0.264
# 5                   0.0680        diamagnetic   1.148
# 6                  -0.1770       paramagnetic   4.572
# 7                   0.1240      ferromagnetic   6.436
# 8                  -0.0075      ferromagnetic   9.305
# 9                   0.1955      ferromagnetic   3.485
# 10                  0.2375      ferromagnetic   2.111
# 11                 -0.0730       paramagnetic   4.234
# 12                 -0.0350       paramagnetic   3.477
# 13                  0.0470      ferromagnetic   5.168
# 14                  0.2005        diamagnetic   3.796
# 15                  0.0850       paramagnetic   5.484
# 16                  0.0045        diamagnetic   0.000
# 17                  0.0100        diamagnetic  25.221
# 18                 -0.0085       paramagnetic   7.677
# 19                 -0.1110       paramagnetic  12.948
# 20                  0.0695        diamagnetic  18.245
# 21                 -0.1785       paramagnetic   0.264
# 22                  0.0115        diamagnetic   4.807
# 23                  0.0100        diamagnetic   4.771
# 24                 -0.9575       paramagnetic   5.484
# 25                 -0.0885       paramagnetic   0.264
# 26                 -0.0045       paramagnetic   7.677
# 27                  0.0050        diamagnetic  25.221
# 28                  0.0000      ferromagnetic     NaN

# %% [markdown]
# ## Calculating the $\chi_m$

# %%
area = 1*1*u.cm**2
mu0 = 1.25663706212*10**-6 *u.H/u.m
g = 9.8*u.m/u.s**2
print(holder := mu0*g/(area*u.T**2))
print(f"{holder.decompose().to(1/u.g):e}")

mu0 = 1.25663706212*10**-6
area = 1*1
g = ufloat(9.8026, 0.01)
# Out:
# 1.2315043208776e-05 H / (cm2 s2 T2)
# 1.231504e-04 1 / g

# %%
data["our chi"] = -10*(data['high/low diff diff avg']*(ufloat(2,np.sqrt(0.001**2+0.001**2)/2))*mu0*g/(area*B**2))
data["diff"] = (data["online chi(cm3/mol)"] - data["our chi"])/data["online chi(cm3/mol)"]

# calculating volume
data["volume"] = data["height(cm)"] * 1*1
data["our chi molar"] = data["our chi"]*data["molar mass"]*data["volume"]/data["mass(g)"]

# data["online chi(cm3/mol)"] *= 10**6
# data["our chi"] *= 10**6
# data["our chi molar"] *= 10**6

# %%
data["chi molar diff"] = 100*(data["online chi(cm3/mol)"]-data["our chi molar"])/data["online chi(cm3/mol)"]

# %%
data.loc[data["name"] == " colbalt wire", "volume"] *= np.pi*((127*10**-4)/2)**2
print(data["volume"][data["name"] == " colbalt wire"])
# Out:
# 4     0.000405
# 21    0.000405
# 25    0.000405
# Name: volume, dtype: float64

# %%
data[["name","online chi(cm3/mol)","our classification","our chi molar","chi molar diff"]]
# Out:
#                                name  online chi(cm3/mol) our classification  \
# 0                            copper            -0.000005        diamagnetic
# 1                          aluminum             0.000017       paramagnetic
# 2                          titanium             0.000153       paramagnetic
# 3                           bismuth            -0.000280        diamagnetic
# 4                      colbalt wire                  NaN       paramagnetic
# 5                pyrolytic graphite                  NaN        diamagnetic
# 6     neodymium choride hexahydrate                  NaN       paramagnetic
# 7                  gadolinium oxide             0.053200      ferromagnetic
# 8                      erbium oxide             0.073920      ferromagnetic
# 9                        mohrs salt                  NaN      ferromagnetic
# 10                        irom alum                  NaN      ferromagnetic
# 11                     blue vitriol             0.001330       paramagnetic
# 12                   copper acetate                  NaN       paramagnetic
# 13                  manganese oxide             0.004850      ferromagnetic
# 14   manganese choride tetrahydrate             0.014350        diamagnetic
# 15              nickel-zinc ferrite                  NaN       paramagnetic
# 16                       empty vial                  NaN        diamagnetic
# 17                           copper            -0.000005        diamagnetic
# 18                         aluminum             0.000017       paramagnetic
# 19                         titanium             0.000153       paramagnetic
# 20                          bismuth            -0.000280        diamagnetic
# 21                     colbalt wire                  NaN       paramagnetic
# 22                     iodized salt                  NaN        diamagnetic
# 23                   himalanan salt                  NaN        diamagnetic
# 24              nickel-zinc ferrite                  NaN       paramagnetic
# 25                     colbalt wire                  NaN       paramagnetic
# 26                         aluminum             0.000017       paramagnetic
# 27                           copper            -0.000005        diamagnetic
# 28                    Rust on paper                  NaN      ferromagnetic
#
#              our chi molar      chi molar diff
# 0                nan+/-nan           nan+/-nan
# 1                nan+/-nan           nan+/-nan
# 2                nan+/-nan           nan+/-nan
# 3                nan+/-nan           nan+/-nan
# 4                nan+/-nan           nan+/-nan
# 5     -0.001043+/-0.000021           nan+/-nan
# 6          0.0428+/-0.0008           nan+/-nan
# 7         -0.0266+/-0.0005         150.0+/-1.0
# 8      0.001281+/-0.000025      98.267+/-0.034
# 9         -0.0623+/-0.0012           nan+/-nan
# 10        -0.1184+/-0.0023           nan+/-nan
# 11       0.01451+/-0.00029           -991+/-22
# 12       0.00586+/-0.00012           nan+/-nan
# 13      -0.00195+/-0.00004         140.1+/-0.8
# 14        -0.1574+/-0.0031           1197+/-22
# 15      -0.01312+/-0.00026           nan+/-nan
# 16               nan+/-nan           nan+/-nan
# 17  -0.0001179+/-0.0000023  (-2.06+/-0.04)e+03
# 18   0.0001058+/-0.0000021           -541+/-13
# 19     0.001637+/-0.000032           -970+/-21
# 20      -0.00369+/-0.00007          -1219+/-26
# 21       0.01714+/-0.00034           nan+/-nan
# 22    -0.000495+/-0.000010           nan+/-nan
# 23    -0.000458+/-0.000009           nan+/-nan
# 24         0.1478+/-0.0029           nan+/-nan
# 25       0.00850+/-0.00017           nan+/-nan
# 26       (5.60+/-0.11)e-05            -239+/-7
# 27      (-5.89+/-0.12)e-05           -979+/-21
# 28               nan+/-nan           nan+/-nan

# %% [markdown]
# ## Linearality of B-field
# Finding the linearality of the B-field for a dia-, para-, and ferro- magnet

# %%
para_lin = pd.read_csv("lab01_al_linearity.csv")
dia_lin = pd.read_csv("lab01_cu_linearity.csv")
ferro_lin = pd.read_csv("lab01_co_linearity.csv")
para_lin["mass"] -= .758
dia_lin["mass"] -= .760
ferro_lin["mass"] -= .765
h_scale = 0.635 #make the height in mm

# %%
func = lambda x, a, b: a*x +b
xlin1 = np.linspace(-40*h_scale,0,100)
xlin2 = np.linspace(0,40*h_scale,100)

def linear_B_test(arr, name):
    heights = h_scale*arr['rotations']
    mass = arr['mass']
    
    # plotting delta m with linear fit
    popt1, pcov1 = curve_fit(func, heights[11:-1], mass[11:-1], p0=None)
    popt2, pcov2 = curve_fit(func, heights[0:10], mass[0:10], p0=None)
    yer = 0.002*np.ones(len(heights))
    plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.3f g'))
    plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f mm'))
    plt.xticks(rotation=45)
    plt.errorbar(heights,mass,yerr=yer,label=name,fmt='o')
    plt.plot(xlin1, func(xlin1, *popt1), 'r')
    plt.plot(xlin2, func(xlin2, *popt2), 'r')
    plt.hlines(0,-40*h_scale,40*h_scale,color="black")
    plt.title(r"$\Delta$m vs. heights (" + name + "magnet)")
    plt.savefig(name + "_linearity.png")
    plt.show()
    return

linear_B_test(para_lin, "para")
linear_B_test(dia_lin, "dia")
linear_B_test(ferro_lin, "ferro")

# %% [markdown]
# # references for molar masses
# https://www.webqc.org/molecular-weight-of-Cu.html <br>
# https://www.webqc.org/molecular-weight-of-Al.html <br>
# https://www.webqc.org/molecular-weight-of-titanium.html <br>
# https://www.webqc.org/molecular-weight-of-bismuth.html <br>
# https://www.webqc.org/molecular-weight-of-cobalt.html <br>
# https://www.alfa-chemistry.com/product/pyrolytic-graphite-powder-cas-7782-42-5-282338.html <br>
# http://www.endmemo.com/chem/compound/ndcl36h2o.php <br>
# https://www.convertunits.com/molarmass/Gadolinium(III)+Oxide <br>
# https://www.convertunits.com/molarmass/Erbium(III)+Oxide <br>
# https://byjus.com/chemistry/mohrs-salt/ <br>
# https://en.wikipedia.org/wiki/Ammonium_iron(III)_sulfate <br>
# https://en.wikipedia.org/wiki/Copper(II)_sulfate <br>
# https://en.wikipedia.org/wiki/Copper(II)_acetate <br>
# https://www.webqc.org/molecular-weight-of-MnO.html <br>
# https://www.webqc.org/molecular-weight-of-MnCl2+4H20.html <br>
# https://www.webqc.org/molecular-weight-of-Ni+Fe2+O4.html <br>
# https://www.webqc.org/molecular-weight-of-NaCl.html <br>
# https://themeadow.com/pages/minerals-in-himalayan-pink-salt-spectral-analysis - make up of himalanan salt

# %%
data
# Out:
#             sample                             name   low(g)  high(g)  \
# 0                1                           copper  180.764  180.782
# 1                2                         aluminum  180.779  180.762
# 2                3                         titanium  180.874  180.656
# 3                4                          bismuth  180.701  180.842
# 4                5                     colbalt wire  180.941  180.579
# 5                6               pyrolytic graphite  180.705  180.841
# 6                7    neodymium choride hexahydrate  180.939  180.585
# 7                8                 gadolinium oxide  180.155  180.403
# 8                9                     erbium oxide  180.480  180.465
# 9               10                       mohrs salt  180.035  180.426
# 10              11                        irom alum  180.020  180.495
# 11              12                     blue vitriol  180.839  180.693
# 12              13                   copper acetate  180.804  180.734
# 13              14                  manganese oxide  180.472  180.566
# 14              15   manganese choride tetrahydrate  180.512  180.913
# 15              16              nickel-zinc ferrite  180.622  180.792
# 16              17                       empty vial  180.771  180.780
# 17        1 (redo)                           copper  180.764  180.784
# 18        2 (redo)                         aluminum  180.781  180.764
# 19        3 (redo)                         titanium  180.877  180.655
# 20        4 (redo)                          bismuth  180.705  180.844
# 21        5 (redo)                     colbalt wire  180.943  180.586
# 22              1*                     iodized salt  180.746  180.769
# 23              2*                   himalanan salt  180.748  180.768
# 24       16 (redo)              nickel-zinc ferrite  181.692  179.777
# 25  5 (second day)                     colbalt wire  180.757  180.580
# 26  2 (second day)                         aluminum  180.762  180.753
# 27  1 (second day)                           copper  180.760  180.770
# 28              18                    Rust on paper  180.763  180.763
#
#      far(g)     init online classification  online chi(cm3/mol)  height(cm)  \
# 0   180.772      NaN           diamagnetic            -0.000005        3.20
# 1   180.772      NaN          paramagnetic             0.000017        3.00
# 2   180.772      NaN          paramagnetic             0.000153        3.00
# 3   180.772      NaN           diamagnetic            -0.000280        3.30
# 4   180.771      NaN         ferromagnetic                  NaN        3.20
# 5   180.771  180.772                   NaN                  NaN        3.20
# 6   180.772  180.772          paramagnetic                  NaN        3.10
# 7   180.768  180.774                   NaN             0.053200        3.40
# 8   180.767  180.773                   NaN             0.073920        3.35
# 9   180.774  180.773                   NaN                  NaN        3.20
# 10  180.773  180.772          paramagnetic                  NaN        3.20
# 11  180.772  180.770                   NaN             0.001330        3.50
# 12  180.771  180.771                   NaN                  NaN        3.30
# 13  180.770  180.772                   NaN             0.004850        2.90
# 14  180.772  180.775                   NaN             0.014350        3.50
# 15  180.772  180.776          paramagnetic                  NaN        3.40
# 16  180.776  180.775                   NaN                  NaN        3.85
# 17  180.775  180.774           diamagnetic            -0.000005        3.20
# 18  180.774  180.774          paramagnetic             0.000017        3.00
# 19  180.774  180.775          paramagnetic             0.000153        3.00
# 20  180.775  180.774           diamagnetic            -0.000280        3.30
# 21  180.766  180.766         ferromagnetic                  NaN        3.20
# 22  180.759  180.759                   NaN                  NaN        3.50
# 23  180.758  180.758                   NaN                  NaN        3.70
# 24  180.762  180.772          paramagnetic                  NaN        3.40
# 25  180.939  180.762         ferromagnetic                  NaN        3.20
# 26  180.771  180.763          paramagnetic             0.000017        3.00
# 27  180.749  180.760           diamagnetic            -0.000005        3.20
# 28  180.759  180.760                   NaN                  NaN         NaN
#
#     mass(g)  ... low diff  high/low diff diff  high/low diff diff avg  \
# 0    28.163  ...      NaN                 NaN                     NaN
# 1    10.619  ...      NaN                 NaN                     NaN
# 2    15.890  ...      NaN                 NaN                     NaN
# 3    21.187  ...      NaN                 NaN                     NaN
# 4     3.206  ...      NaN                 NaN                     NaN
# 5     4.090  ...   -0.067               0.136                  0.0680
# 6     7.514  ...    0.167              -0.354                 -0.1770
# 7     9.378  ...   -0.619               0.248                  0.1240
# 8    12.247  ...   -0.293              -0.015                 -0.0075
# 9     6.427  ...   -0.738               0.391                  0.1955
# 10    5.053  ...   -0.752               0.475                  0.2375
# 11    7.176  ...    0.069              -0.146                 -0.0730
# 12    6.419  ...    0.033              -0.070                 -0.0350
# 13    8.110  ...   -0.300               0.094                  0.0470
# 14    6.738  ...   -0.263               0.401                  0.2005
# 15    8.426  ...   -0.154               0.170                  0.0850
# 16    2.942  ...   -0.004               0.009                  0.0045
# 17   28.163  ...   -0.010               0.020                  0.0100
# 18   10.619  ...    0.007              -0.017                 -0.0085
# 19   15.890  ...    0.102              -0.222                 -0.1110
# 20   21.187  ...   -0.069               0.139                  0.0695
# 21    3.206  ...    0.177              -0.357                 -0.1785
# 22    7.749  ...   -0.013               0.023                  0.0115
# 23    7.713  ...   -0.010               0.020                  0.0100
# 24    8.426  ...    0.920              -1.915                 -0.9575
# 25    3.206  ...   -0.005              -0.177                 -0.0885
# 26   10.619  ...   -0.001              -0.009                 -0.0045
# 27   28.163  ...    0.000               0.010                  0.0050
# 28      NaN  ...    0.003               0.000                  0.0000
#
#     our classification    mass                 our chi                   diff  \
# 0          diamagnetic  25.221               nan+/-nan              nan+/-nan
# 1         paramagnetic   7.677               nan+/-nan              nan+/-nan
# 2         paramagnetic  12.948               nan+/-nan              nan+/-nan
# 3          diamagnetic  18.245               nan+/-nan              nan+/-nan
# 4         paramagnetic   0.264               nan+/-nan              nan+/-nan
# 5          diamagnetic   1.148  -0.0001110+/-0.0000022              nan+/-nan
# 6         paramagnetic   4.572     0.000289+/-0.000006              nan+/-nan
# 7        ferromagnetic   6.436    -0.000202+/-0.000004      1.00380+/-0.00008
# 8        ferromagnetic   9.305     (1.224+/-0.024)e-05  0.9998344+/-0.0000033
# 9        ferromagnetic   3.485    -0.000319+/-0.000006              nan+/-nan
# 10       ferromagnetic   2.111    -0.000388+/-0.000008              nan+/-nan
# 11        paramagnetic   4.234   0.0001192+/-0.0000024        0.9104+/-0.0018
# 12        paramagnetic   3.477       (5.71+/-0.11)e-05              nan+/-nan
# 13       ferromagnetic   5.168      (-7.67+/-0.15)e-05      1.01582+/-0.00031
# 14         diamagnetic   3.796    -0.000327+/-0.000006        1.0228+/-0.0005
# 15        paramagnetic   5.484  -0.0001387+/-0.0000028              nan+/-nan
# 16         diamagnetic   0.000      (-7.34+/-0.15)e-06              nan+/-nan
# 17         diamagnetic  25.221    (-1.632+/-0.032)e-05           -1.99+/-0.06
# 18        paramagnetic   7.677     (1.387+/-0.028)e-05          0.159+/-0.017
# 19        paramagnetic  12.948     0.000181+/-0.000004         -0.184+/-0.023
# 20         diamagnetic  18.245  -0.0001134+/-0.0000022          0.595+/-0.008
# 21        paramagnetic   0.264     0.000291+/-0.000006              nan+/-nan
# 22         diamagnetic   4.807      (-1.88+/-0.04)e-05              nan+/-nan
# 23         diamagnetic   4.771    (-1.632+/-0.032)e-05              nan+/-nan
# 24        paramagnetic   5.484     0.001563+/-0.000031              nan+/-nan
# 25        paramagnetic   0.264   0.0001445+/-0.0000029              nan+/-nan
# 26        paramagnetic   7.677       (7.34+/-0.15)e-06          0.555+/-0.009
# 27         diamagnetic  25.221      (-8.16+/-0.16)e-06         -0.495+/-0.030
# 28       ferromagnetic     NaN                -0.0+/-0              nan+/-nan
#
#       volume           our chi molar      chi molar diff
# 0   3.200000               nan+/-nan           nan+/-nan
# 1   3.000000               nan+/-nan           nan+/-nan
# 2   3.000000               nan+/-nan           nan+/-nan
# 3   3.300000               nan+/-nan           nan+/-nan
# 4   0.000405               nan+/-nan           nan+/-nan
# 5   3.200000    -0.001043+/-0.000021           nan+/-nan
# 6   3.100000         0.0428+/-0.0008           nan+/-nan
# 7   3.400000        -0.0266+/-0.0005         150.0+/-1.0
# 8   3.350000     0.001281+/-0.000025      98.267+/-0.034
# 9   3.200000        -0.0623+/-0.0012           nan+/-nan
# 10  3.200000        -0.1184+/-0.0023           nan+/-nan
# 11  3.500000       0.01451+/-0.00029           -991+/-22
# 12  3.300000       0.00586+/-0.00012           nan+/-nan
# 13  2.900000      -0.00195+/-0.00004         140.1+/-0.8
# 14  3.500000        -0.1574+/-0.0031           1197+/-22
# 15  3.400000      -0.01312+/-0.00026           nan+/-nan
# 16  3.850000               nan+/-nan           nan+/-nan
# 17  3.200000  -0.0001179+/-0.0000023  (-2.06+/-0.04)e+03
# 18  3.000000   0.0001058+/-0.0000021           -541+/-13
# 19  3.000000     0.001637+/-0.000032           -970+/-21
# 20  3.300000      -0.00369+/-0.00007          -1219+/-26
# 21  0.000405       0.01714+/-0.00034           nan+/-nan
# 22  3.500000    -0.000495+/-0.000010           nan+/-nan
# 23  3.700000    -0.000458+/-0.000009           nan+/-nan
# 24  3.400000         0.1478+/-0.0029           nan+/-nan
# 25  0.000405       0.00850+/-0.00017           nan+/-nan
# 26  3.000000       (5.60+/-0.11)e-05            -239+/-7
# 27  3.200000      (-5.89+/-0.12)e-05           -979+/-21
# 28       NaN               nan+/-nan           nan+/-nan
#
# [29 rows x 23 columns]

# %%
plt.plot(data["sample"],data["init"])
plt.title("Magnet apparatus weight")
plt.grid(False)
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.3f g'))
plt.gca().xaxis.set_major_formatter("")
plt.savefig("init_weight.png")
plt.show()
