# %%
import astropy.units as u
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
matplotlib.use('nbagg')

# %%
ls data\day1
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4E89-5B0C
#
#  Directory of C:\Users\WillsPc\GitHub\AdvancedLab-PHSX444\lab03\data\day1
#
# 10/15/2021  10:48 AM    <DIR>          .
# 10/15/2021  10:48 AM    <DIR>          ..
# 10/15/2021  04:47 PM         2,355,254 horizontal_calibration.bmp
# 10/15/2021  04:47 PM         2,355,254 horizontal_calibrationv2.bmp
# 10/15/2021  04:47 PM         2,355,254 the_goat.bmp
# 10/15/2021  04:47 PM           326,349 the_goat.jpg
# 10/15/2021  04:47 PM           214,714 the_goat1.jpg
# 10/15/2021  04:47 PM         2,355,254 vertical_calibration.bmp
#                6 File(s)      9,962,079 bytes
#                2 Dir(s)  379,225,018,368 bytes free

# %%
import imageio
im = imageio.imread("data/day1/horizontal_calibrationv2.bmp")

# %%
plt.figure(figsize=(21,14))
plt.imshow(im,aspect='auto',origin='lower')
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1512">

# %%
xscale = (1007 + (1058-1007)/2) - (980 + (-980+1007)/2)
