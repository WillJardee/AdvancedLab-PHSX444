# %%
# imports
import jupyterthemes as jt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy.fft import fft, ifft
jt.jtplot.style()

# %matplotlib inline

# %%
#Stating theme
import jupyterthemes as jt
# !jt -t gruvboxl -T -N -kl -nfs 11 -fs 11 -ofs 11 -cursc r -cellw 90%
jt.jtplot.style()
jt.get_themes()
# Out:
# ['chesterish',
#  'grade3',
#  'gruvboxd',
#  'gruvboxl',
#  'monokai',
#  'oceans16',
#  'onedork',
#  'solarizedd',
#  'solarizedl']

# %%
color2, color1 = '#0091d4', '#d44300'  #red

# %%
def fft_plot(osc_path, osc_name, spec_path, spec_name, window="uniform", do_dBV=False, title=' '):
    data = pd.read_csv(osc_path + osc_name, header=None)
    df = pd.read_csv(spec_path + spec_name, header=None)
    
    times = data[3]
    voltages = data[4]

    if window == "uniform":
        pass
    elif window == "hanning":
        voltages *= np.hanning(data[3].size)
    elif window == "kaiser":
        voltages *= np.kaiser(data[3].size, beta)
    elif window == "hamming":
        voltages *= np.hamming(data[3].size)
    elif window == "bartlett":
        voltages *= np.bartlett(data[3].size)
    elif window == "blackman":
        voltages *= np.blackman(data[3].size)
        

    N = len(times)
    dt = float(np.array(data[data[0] == 'Sample Interval'][1])[0])

    Ys = np.fft.rfft(voltages)
    fs = np.fft.rfftfreq(N, dt)

    vert = np.sqrt(2)*np.abs(Ys) / N
    
    if do_dBV:
        vert = 20*np.log10(vert)

        
    # Plotting
    plt.figure(figsize=(21, 6))
    plt.subplot(121)
    plt.plot(fs, vert, c=color1, label='FFT from oscilloscope',linewidth=1.5)
    plt.plot(df[0], df[1], c=color2, label='FFT from spectrum analyzer',)

    plt.xlim(0,np.max(df[0])) 
    
    plt.subplot(122)
    plt.plot(times, voltages)

# %%
ls data\part_1\part_a_spectrum_analyzer\uniform_sin_1_1khz.csv
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F64F-FF16
#
#  Directory of C:\Users\jarde\Documents\GitHub\AdvancedLab-PHSX444\lab02\data\part_1\part_a_spectrum_analyzer
#
# 10/16/2021  02:17 PM    <DIR>          .
# 10/16/2021  02:17 PM    <DIR>          ..
# 10/16/2021  02:17 PM            14,400 hanning_sin_1_1.03khz.csv
# 10/16/2021  02:17 PM            14,400 hanning_sin_1_1khz.csv
# 10/16/2021  02:17 PM            14,400 hanning_squr_1_1.03khz.csv
# 10/16/2021  02:17 PM            14,400 hanning_squr_1_1khz.csv
# 10/16/2021  02:17 PM            14,400 hanning_tri_1_1.03khz.csv
# 10/16/2021  02:17 PM            14,400 hanning_tri_1_1khz.csv
# 10/16/2021  02:17 PM            14,400 uniform_sin_1_1.03khz.csv
# 10/16/2021  02:17 PM            14,400 uniform_sin_1_1khz.csv
# 10/16/2021  02:17 PM            14,400 uniform_squr_1_1.03khz.csv
# 10/16/2021  02:17 PM            14,400 uniform_squr_1_1khz.csv
# 10/16/2021  02:17 PM            14,400 uniform_tri_1_1.03khz.csv
# ...

# %%
data = ("data/part_1/part_a_oscilloscope/", "sin_1_1.03khz.CSV", "data/part_1/part_a_spectrum_analyzer/", "uniform_sin_1_1khz.csv")
title = ''
fft_plot(*data, do_dBV = True)

data = ("data/part_1/part_a_oscilloscope/", "sin_1_1.03khz.CSV", "data/part_1/part_a_spectrum_analyzer/", "hanning_sin_1_1khz.csv")
fft_plot(*data, window='hanning', do_dBV=True)
