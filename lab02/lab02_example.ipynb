# %% [markdown]
# Think about using interactive tables: <br>
# <ul>
#     <li> <a href="https://pypi.org/project/itables/">iTables</a> </li>
#     <li> <a href="https://towardsdatascience.com/two-essential-pandas-add-ons-499c1c9b65de">Pivot Tables</a> </li>
# </ul>

# %% [markdown]
# More useful links <br>
# <ul>
#     <li> <a href="https://medium.com/data-science-bootcamp/anaconda-miniconda-cheatsheet-for-data-scientists-2c1be12f56db">Conda Cheat Sheet</a> </li>
# </ul>

# %%
conda list
# Out:
# # packages in environment at C:\ProgramData\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2021.05                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        2.0.4                    py38_0
# anaconda-project          0.9.1              pyhd3eb1b0_1
# anyio                     2.2.0            py38haa95532_2
# appdirs                   1.4.4                      py_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38h2bbff1b_1
# asn1crypto                1.4.0                      py_0
# astroid                   2.5              py38haa95532_1
# astroplan                 0.8                      pypi_0    pypi
# astropy                   4.2.1            py38h2bbff1b_1
# ...

# %%
#Stating theme
import jupyterthemes as jt
# !jt -t solarizedl -T -N -kl -nfs 11 -fs 11 -ofs 11 -cursc r -cellw 90%
jt.jtplot.style()
jt.get_themes()
# Out:
# ['chesterish',
#  'grade3',
#  'gruvboxd',
#  'gruvboxl',
#  'monokai',
#  'oceans16',
#  'onedork',
#  'solarizedd',
#  'solarizedl']

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy.fft import fft, ifft

# %matplotlib inline

# %% [markdown]
# Code stolen from:
# https://pythonnumericalmethods.berkeley.edu/notebooks/chapter24.04-FFT-in-Python.html
#
# There are examples on there, including one that shows how to use pandas to import this info.

# %%
# # sampling rate
# sr = 2000
# # sampling interval
# ts = 1.0/sr
# t = np.arange(0,1,ts)

# freq = 1.
# x = 3*np.sin(2*np.pi*freq*t)

# freq = 4
# x += np.sin(2*np.pi*freq*t)

# freq = 7   
# x += 0.5* np.sin(2*np.pi*freq*t)

# plt.figure(figsize = (8, 6))
# plt.plot(t, x, 'r')
# plt.ylabel('Amplitude')

# plt.show()

# %%
# from numpy.fft import fft, ifft

# # x is my provided data
# # sr is the sampling rate
# X = fft(x)
# N = len(X)
# n = np.arange(N)
# T = N/sr
# freq = n/T 

# plt.figure(figsize = (12, 6))
# plt.subplot(121)

# plt.stem(freq, np.abs(X), 'b', \
#          markerfmt=" ", basefmt="-b")
# plt.xlabel('Freq (Hz)')
# plt.ylabel('FFT Amplitude |X(freq)|')
# plt.xlim(0, 10)

# plt.subplot(122)
# plt.plot(t, ifft(X), 'r')
# plt.xlabel('Time (s)')
# plt.ylabel('Amplitude')
# plt.tight_layout()
# plt.show()

# %%
ls C:\Users\WillsPc\OneDrive\Classes\phsx441\lab02\data
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4E89-5B0C
#
#  Directory of C:\Users\WillsPc\OneDrive\Classes\phsx441\lab02\data
#
# 10/01/2021  10:22 AM    <DIR>          .
# 10/01/2021  10:22 AM    <DIR>          ..
# 04/01/1994  02:03 AM            14,400 hanning_sin_1_1.03khz.csv
# 10/01/2021  09:37 AM    <DIR>          part_1
# 10/01/2021  10:43 AM    <DIR>          part_2
# 09/24/2021  09:01 AM    <DIR>          trash
# 04/01/1994  02:01 AM            14,400 uniform_sin_1_1.03khz.csv
#                2 File(s)         28,800 bytes
#                5 Dir(s)  403,233,828,864 bytes free

# %%
def plotter(file, name):
    df = pd.read_csv(file, header=None)
    plt.figure(figsize=(14, 6))
    plt.plot(df[0], df[1]-np.min(df[1]))
    # plt.yscale("log")
    plt.title(name)
    plt.show()

# %%
plotter("data/part_1/hanning_sin_1_1khz.csv","hanning 1khz")
plotter("data/part_1/hanning_sin_1_1.03khz.csv", "hanning 1.03khz")
plotter("data/part_1/uniform_sin_1_1khz.csv", "uniform 1khz")
plotter("data/part_1/uniform_sin_1_1.03khz.csv", "uniform 1.03khz")

# %%
plotter("data/part_1/hanning_squr_1_1khz.csv","hanning 1khz")
plotter("data/part_1/hanning_squr_1_1.03khz.csv", "hanning 1.03khz")
plotter("data/part_1/uniform_squr_1_1khz.csv", "uniform 1khz")
plotter("data/part_1/uniform_squr_1_1.03khz.csv", "uniform 1.03khz")

# %%
plotter("data/part_1/hanning_tri_1_1khz.csv","hanning 1khz")
plotter("data/part_1/hanning_tri_1_1.03khz.csv", "hanning 1.03khz")
plotter("data/part_1/uniform_tri_1_1khz.csv", "uniform 1khz")
plotter("data/part_1/uniform_tri_1_1.03khz.csv", "uniform 1.03khz")

# %%
df = pd.read_csv("data/part_1/oscilloscope_sin/F0005FFT_this.csv", header=None)
plt.plot(df[0], df[1])
plt.yscale('log')
# plt.xlim(0,12500)
plt.title("hanning 1khz")

# df = pd.read_csv("data/part_1/hanning_sin_1_1.03khz.csv", header=None)
# plt.plot(df[0], df[1])
# plt.title("hanning 1.03khz")
# plt.show()

# df = pd.read_csv("data/part_1/uniform_sin_1_1khz.csv", header=None)
# plt.plot(df[0], df[1])
# plt.title("uniform 1khz")

# df = pd.read_csv("data/part_1/uniform_sin_1_1.03khz.csv", header=None)
# plt.plot(df[0], df[1])
# plt.title("uniform 1.03khz")
# # plt.xlim(0, 12500)
# plt.show()
# Out:
# <ipython-input-10-66689981bbfd>:3: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')
# Text(0.5, 1.0, 'hanning 1khz')

# %%
def my_fft(file):
    # x is my provided data
    x = pd.read_csv(file, header=None)
    sr = 1e6
    # sr is the sampling rate
    data = x[4]
    data *= np.hanning(x[3].size)
    X = fft(data)
    N = len(X)
    n = np.arange(N)
    T = N/sr
    freq = n/T 

    plt.figure(figsize = (20, 6))
    plt.subplot(121)

    plt.stem(freq, np.abs(X), 'b', \
            markerfmt=" ", basefmt="-b")
    #plt.yscale('log')
    plt.ylim(np.sqrt(np.max(np.abs(X))), 1.10*np.max(np.abs(X)))
    # plt.xlim(9e5,11e5)
    plt.xlabel('Freq (Hz)')
    plt.ylabel('FFT Amplitude |X(freq)|')
    # plt.xlim(0, 10)

    plt.subplot(122)
    plt.plot(x[3], ifft(X), 'r')
    # plt.xlim(x[3][0],np.median(x[3]))
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.tight_layout()
    plt.show()

# %%
osc_files = 'data/part_1/oscilloscope_sin_4/'

# %%
my_fft(osc_files + "F0000CH1.csv")
my_fft(osc_files + "F0001CH1.csv")
my_fft(osc_files + "F0002CH1.csv")
my_fft(osc_files + "F0003CH1.csv")
my_fft(osc_files + "F0004CH1.csv")
my_fft(osc_files + "F0005CH1.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
my_fft('data\part_1\oscilloscope_summer\F0001CH1.CSV')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ls data\part_1\osci_mult\retry\F0000CH1.CSV
# Out:
#  Volume in drive C is OS
# File Not Found
#  Volume Serial Number is 4E89-5B0C
#
#  Directory of C:\Users\WillsPc\OneDrive\Classes\phsx441\lab02\data\part_1\osci_mult\retry

# %%
my_fft('data\part_1\osci_mult\F0000CH1_1.CSV')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
my_fft('data\part_1' + '\\' + 'buried_treasuer\F0001CH1.CSV')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ls data\part_1\buried_treasuer\F0001CH1.CSV
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4E89-5B0C
#
#  Directory of C:\Users\WillsPc\OneDrive\Classes\phsx441\lab02\data\part_1\buried_treasuer
#
# 10/01/2021  10:54 PM            79,079 F0001CH1.CSV
#                1 File(s)         79,079 bytes
#                0 Dir(s)  403,233,726,464 bytes free
